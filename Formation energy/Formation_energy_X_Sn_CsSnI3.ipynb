# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

# %% [markdown]
# # I-rich condition
# ## Sn-site I-rich condition

# %%
u_bi = -6.62
u_sb = -7.39
u_as = -6.21
u_sc = -13.60
u_ti = -15.04
u_y  = -14.37
u_zr = -15.58
u_al = -6.74
u_ca = -7.13
u_ga = -5.60
u_in = -5.09
u_cd = -3.10
u_cu = -4.67
u_mo = -17.21
u_mn = -22.02
u_nb = -16.51
u_zn = -3.20
u_w  = -17.35
u_ag = -4.13
u_au = -4.32
u_ni = -10.68
u_v  = -18.53
u_mg = -4.76
u_pd = -8.10
u_ge = -6.82
u_cr = -20.10

u_sn = -5.98
u_cs = -4.54

vbm = 1.82
Eclean = -332.65
fermi=np.arange(0,1.6728,0.01)

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)
ax=fig.add_subplot(1,1,1)

##Zr_Sn##
nzr=+1
nsn=-1

q=0
Etot=-340.65
E_f0=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.90
E_f_p1=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#E7CBCB', linewidth=3, label='Zr_Sn')

##As_Sn##
nas=+1
nsn=-1

q=0
Etot=-332.56
E_f0=Etot-Eclean-nas*u_as-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-334.96
E_f_p1=Etot-Eclean-nas*u_as-nsn*u_sn+q*fermi+q*vbm+0.12

q=+2
Etot=-336.75
E_f_p2=Etot-Eclean-nas*u_as-nsn*u_sn+q*fermi+q*vbm+0.53

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#F1C27B', linewidth=3, label='As_Sn')

##Sb_Sn##
nsb=+1
nsn=-1

q=0
Etot=-333.16
E_f0=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.82
E_f_p1=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*fermi+q*vbm+0.08

q=+2
Etot=-337.01
E_f_p2=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*fermi+q*vbm+0.54

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FFEADD', linewidth=3, label='Sb_Sn')

##In_Sn##
nin=+1
nsn=-1

q=0
Etot=-331.27
E_f0=Etot-Eclean-nin*u_in-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-333.58
E_f_p1=Etot-Eclean-nin*u_in-nsn*u_sn+q*fermi+q*vbm+0.09

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='In_Sn')

##Bi_Sn##
nbi=+1
nsn=-1

q=0
Etot=-332.86
E_f0=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.29
E_f_p1=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*fermi+q*vbm+0.15

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FCAEAE', linewidth=3, label='Bi_Sn')

##Sc_Sn##
nsc=+1
nsn=-1

q=0
Etot=-339.17
E_f0=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-342.39
E_f_p1=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#643843', linewidth=3, label='Sc_Sn')

##Ga_Sn##
nga=+1
nsn=-1

q=0
Etot=-331.335
E_f0=Etot-Eclean-nga*u_ga-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-333.840
E_f_p1=Etot-Eclean-nga*u_ga-nsn*u_sn+q*fermi+q*vbm+0.09

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ga_Sn')

##Nb_Sn##
nnb=+1
nsn=-1

q=0
Etot=-342.45
E_f0=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-344.69
E_f_p1=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Nb_Sn')

##Mo_Sn##
nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*fermi+q*vbm+0.17

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mo_Sn')

##Mn_Sn##
nmn=+1
nsn=-1

q=0
Etot=-348.52
E_f0=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-350.18
E_f_p1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*fermi+q*vbm+0.15

q=-1
Etot=-345.04
E_f_n1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*fermi+q*vbm+0.11

arr=[E_f_p1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mn_Sn')

##Zn_Sn##
nzn=+1
nsn=-1

q=0
Etot=-330.00
E_f0=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-331.63
E_f_p1=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Zn_Sn')

##Ca_Sn##
nca=+1
nsn=-1

q=0
Etot=-333.76
E_f0=Etot-Eclean-nca*u_ca-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.46
E_f_p1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*fermi+q*vbm+0.15

q=-1
Etot=-330.27
E_f_n1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*fermi+q*vbm+0.10

arr=[E_f_p1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ca_Sn')

##Cd_Sn##
ncd=+1
nsn=-1

q=0
Etot=-329.790
E_f0=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-331.424
E_f_p1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*fermi+q*vbm+0.12

q=-1
Etot=-326.512
E_f_n1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*fermi+q*vbm+0.10

arr=[E_f_p1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cd_Sn')

##Y_Sn##
ny=+1
nsn=-1

q=0
Etot=-339.68
E_f0=Etot-Eclean-ny*u_y-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.16
E_f_p1=Etot-Eclean-ny*u_y-nsn*u_sn+q*fermi+q*vbm+0.10

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#E893CF', linewidth=3, label='Y_Sn')

##Ti_Sn##
nti=+1
nsn=-1

q=0
Etot=-341.62
E_f0=Etot-Eclean-nti*u_ti-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.88
E_f_p1=Etot-Eclean-nti*u_ti-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#C88EA7', linewidth=3, label='Ti_Sn')

##Al_Sn##
nal=+1
nsn=-1

q=0
Etot=-332.382
E_f0=Etot-Eclean-nal*u_al-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.407
E_f_p1=Etot-Eclean-nal*u_al-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Al_Sn')

##Ag_Sn##
nag=+1
nsn=-1

q=0
Etot=-330.702
E_f0=Etot-Eclean-nag*u_ag-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-332.036
E_f_p1=Etot-Eclean-nag*u_ag-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ag_Sn')

##Au_Sn##
nau=+1
nsn=-1

q=0
Etot=-330.854
E_f0=Etot-Eclean-nau*u_au-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-332.167
E_f_p1=Etot-Eclean-nau*u_au-nsn*u_sn+q*fermi+q*vbm+0.11

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Au_Sn')

##Mg_Sn##
nmg=+1
nsn=-1

q=0
Etot=-331.488
E_f0=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-333.112
E_f_p1=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mg_Sn')

##Cu_Sn##
ncu=+1
nsn=-1

q=0
Etot=-331.287
E_f0=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-332.604
E_f_p1=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cu_Sn')

##Ge_Sn##
nge=+1
nsn=-1

q=0
Etot=-333.559
E_f0=Etot-Eclean-nge*u_ge-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.332
E_f_p1=Etot-Eclean-nge*u_ge-nsn*u_sn+q*fermi+q*vbm+0.13

q=+2
Etot=-336.725
E_f_p2=Etot-Eclean-nge*u_ge-nsn*u_sn+q*fermi+q*vbm+0.57

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ge_Sn')

##Pd_Sn##
npd=+1
nsn=-1

q=0
Etot=-334.749
E_f0=Etot-Eclean-npd*u_pd-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.812
E_f_p1=Etot-Eclean-npd*u_pd-nsn*u_sn+q*fermi+q*vbm+0.11

q=+2
Etot=-336.990
E_f_p2=Etot-Eclean-npd*u_pd-nsn*u_sn+q*fermi+q*vbm+0.61

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Pd_Sn')

##W_Sn##
nw=+1
nsn=-1

q=0
Etot=-342.49
E_f0=Etot-Eclean-nw*u_w-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-344.67
E_f_p1=Etot-Eclean-nw*u_w-nsn*u_sn+q*fermi+q*vbm+0.17

q=+2
Etot=-346.26
E_f_p2=Etot-Eclean-nw*u_w-nsn*u_sn+q*fermi+q*vbm+0.52

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='W_Sn')

##V_Sn##
nv=+1
nsn=-1

q=0
Etot=-344.61
E_f0=Etot-Eclean-nv*u_v-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-346.24
E_f_p1=Etot-Eclean-nv*u_v-nsn*u_sn+q*fermi+q*vbm+0.14

q=+2
Etot=-347.37
E_f_p2=Etot-Eclean-nv*u_v-nsn*u_sn+q*fermi+q*vbm+0.49

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='V_Sn')

##Cr_Sn##
ncr=+1
nsn=-1

q=0
Etot=-346.693
E_f0=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-348.333
E_f_p1=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cr_Sn')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)
ax.set_xlim([0, 1.35])
ax.set_ylim([-1.1, 2.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.32, 0.4))
plt.yticks(np.arange(-1.0, 2.05, 0.5))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=5, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.01))
#plt.savefig('I-rich-Sn-doping-site.jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
##Zr_Sn##

nzr=+1
nsn=-1

q=0
Etot=-340.65
E_f0=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*vbm
print('Zr0')
print(E_f0)

q=+1
Etot=-343.90
E_f_p1=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*vbm+0.12
print('Zr1')
print(E_f_p1)

##As_Sn##

nas=+1
nsn=-1

q=0
Etot=-332.56
E_f0=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm
print('As0')
print(E_f0)

q=+1
Etot=-334.96
E_f_p1=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm+0.12
print('As1')
print(E_f_p1)

q=+2
Etot=-336.75
E_f_p2=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm+0.53
print('As2')
print(E_f_p2)

##Sb_Sn##

nsb=+1
nsn=-1

q=0
Etot=-333.16
E_f0=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*vbm
print('Sb0')
print(E_f0)

q=+1
Etot=-335.82
E_f_p1=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*vbm+0.08
print('Sb1')
print(E_f_p1)


##In_Sn##

nin=+1
nsn=-1

q=0
Etot=-331.27
E_f0=Etot-Eclean-nin*u_in-nsn*u_sn+q*vbm
print('In0')
print(E_f0)

q=+1
Etot=-333.58
E_f_p1=Etot-Eclean-nin*u_in-nsn*u_sn+q*vbm+0.09
print('In0')
print(E_f_p1)


##Bi_Sn##

nbi=+1
nsn=-1

q=0
Etot=-332.86
E_f0=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*vbm
print('Bi0')
print(E_f0)

q=+1
Etot=-335.29
E_f_p1=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*vbm+0.15
print('Bi1')
print(E_f_p1)


##Sc_Sn##
nsc=+1
nsn=-1

q=0
Etot=-339.17
E_f0=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*vbm
print('Sc0')
print(E_f0)

q=+1
Etot=-342.39
E_f_p1=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*vbm+0.12
print('Sc1')
print(E_f_p1)


##Ga_Sn##

nga=+1
nsn=-1

q=0
Etot=-331.335
E_f0=Etot-Eclean-nga*u_ga-nsn*u_sn+q*vbm
print('Ga0')
print(E_f0)

q=+1
Etot=-333.840
E_f_p1=Etot-Eclean-nga*u_ga-nsn*u_sn+q*vbm+0.09
print('Ga1')
print(E_f_p1)


##Nb_Sn##

nnb=+1
nsn=-1

q=0
Etot=-342.45
E_f0=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*vbm
print('Nb0')
print(E_f0)

q=+1
Etot=-344.69
E_f_p1=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*vbm+0.12
print('Nb1')
print(E_f_p1)


##Mo_Sn##

nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm
print('Mo0')
print(E_f0)

q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm+0.17
print('Mo1')
print(E_f_p1)

##Mn_Sn##

nmn=+1
nsn=-1

q=0
Etot=-348.52
E_f0=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm
print('Mn0')
print(E_f0)

q=+1
Etot=-350.18
E_f_p1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm+0.15
print('Mn1')
print(E_f_p1)

q=-1
Etot=-345.04
E_f_n1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm+0.12
print('Mn-1')
print(E_f_n1)


##Zn_Sn##

nzn=+1
nsn=-1

q=0
Etot=-330.00
E_f0=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*vbm
print('Zn0')
print(E_f0)

q=+1
Etot=-331.63
E_f_p1=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*vbm+0.13
print('Zn1')
print(E_f_p1)


##Ca_Sn##

nca=+1
nsn=-1

q=0
Etot=-333.76
E_f0=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm
print('Ca0')
print(E_f0)

q=+1
Etot=-335.46
E_f_p1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm+0.15
print('Ca1')
print(E_f_p1)

q=-1
Etot=-330.27
E_f_n1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm+0.1
print('Ca-1')
print(E_f_n1)


##Cd_Sn##

ncd=+1
nsn=-1

q=0
Etot=-329.790
E_f0=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm
print('Cd0')
print(E_f0)

q=+1
Etot=-331.424
E_f_p1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm+0.12
print('Cd1')
print(E_f_p1)

q=-1
Etot=-326.512
E_f_n1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm+0.1
print('Cd-1')
print(E_f_n1)

##Y_Sn##

ny=+1
nsn=-1

q=0
Etot=-339.68
E_f0=Etot-Eclean-ny*u_y-nsn*u_sn+q*vbm
print('Y0')
print(E_f0)

q=+1
Etot=-343.16
E_f_p1=Etot-Eclean-ny*u_y-nsn*u_sn+q*vbm+0.10
print('Y1')
print(E_f_p1)


##Ti_Sn##

nti=+1
nsn=-1

q=0
Etot=-341.62
E_f0=Etot-Eclean-nti*u_ti-nsn*u_sn+q*vbm
print('Ti0')
print(E_f0)

q=+1
Etot=-343.88
E_f_p1=Etot-Eclean-nti*u_ti-nsn*u_sn+q*vbm+0.13
print('Ti1')
print(E_f_p1)


##Al_Sn##

nal=+1
nsn=-1

q=0
Etot=-332.382
E_f0=Etot-Eclean-nal*u_al-nsn*u_sn+q*vbm
print('Al0')
print(E_f0)

q=+1
Etot=-335.407
E_f_p1=Etot-Eclean-nal*u_al-nsn*u_sn+q*vbm+0.13
print('Al1')
print(E_f_p1)


##Ag_Sn##

nag=+1
nsn=-1

q=0
Etot=-330.702
E_f0=Etot-Eclean-nag*u_ag-nsn*u_sn+q*vbm
print('Ag0')
print(E_f0)

q=+1
Etot=-332.036
E_f_p1=Etot-Eclean-nag*u_ag-nsn*u_sn+q*vbm+0.12
print('Ag1')
print(E_f_p1)


##Au_Sn##

nau=+1
nsn=-1

q=0
Etot=-330.854
E_f0=Etot-Eclean-nau*u_au-nsn*u_sn+q*vbm
print('Au0')
print(E_f0)

q=+1
Etot=-332.167
E_f_p1=Etot-Eclean-nau*u_au-nsn*u_sn+q*vbm+0.12
print('Au1')
print(E_f_p1)


##Mg_Sn##

nmg=+1
nsn=-1

q=0
Etot=-331.488
E_f0=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*vbm
print('Mg0')
print(E_f0)

q=+1
Etot=-333.112
E_f_p1=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*vbm+0.12
print('Mg1')
print(E_f_p1)


##Cu_Sn##

ncu=+1
nsn=-1

q=0
Etot=-331.287
E_f0=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*vbm
print('Cu0')
print(E_f0)

q=+1
Etot=-332.604
E_f_p1=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*vbm+0.12
print('Cu1')
print(E_f_p1)


##Ge_Sn##

nge=+1
nsn=-1

q=0
Etot=-333.559
E_f0=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm
print('Ge0')
print(E_f0)

q=+1
Etot=-335.332
E_f_p1=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm+0.13
print('Ge1')
print(E_f_p1)

q=+2
Etot=-336.725
E_f_p2=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm+0.57
print('Ge2')
print(E_f_p2)

##Pd_Sn##

npd=+1
nsn=-1

q=0
Etot=-334.749
E_f0=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm
print('Pd0')
print(E_f0)

q=+1
Etot=-335.812
E_f_p1=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm+0.13
print('Pd1')
print(E_f_p1)

q=+2
Etot=-336.990
E_f_p2=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm+0.57
print('Pd2')
print(E_f_p2)


##W_Sn##

nw=+1
nsn=-1

q=0
Etot=-342.49
E_f0=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm
print('W0')
print(E_f0)

q=+1
Etot=-344.67
E_f_p1=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm+0.13
print('W')
print(E_f_p1)

q=+2
Etot=-346.26
E_f_p2=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm+0.57
print('W2')
print(E_f_p2)


##V_Sn##

nv=+1
nsn=-1

q=0
Etot=-344.61
E_f0=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm
print('V0')
print(E_f0)

q=+1
Etot=-346.24
E_f_p1=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm+0.13
print('V1')
print(E_f_p1)

q=+2
Etot=-347.37
E_f_p2=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm+0.57
print('V2')
print(E_f_p2)


##Cr_Sn##

ncr=+1
nsn=-1

q=0
Etot=-346.693
E_f0=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*vbm
print('Cr0')
print(E_f0)

q=+1
Etot=-348.333
E_f_p1=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*vbm+0.12
print('Cr1')
print(E_f_p1)

##Mo_Sn##

nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm
print('Mo0')
print(E_f0)

q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm+0.17
print('Mo1')
print(E_f_p1)
# Out:
# Zr0
# 1.5999999999999996
# Zr1
# 0.2899999999999997
# As0
# 0.3199999999999745
# As1
# -0.14000000000000268
# As2
# 0.29999999999997695
# Sb0
# 0.8999999999999515
# Sb1
# 0.13999999999998342
# In0
# 0.4899999999999949
# In0
# 0.08999999999999267
# Bi0
# 0.4299999999999633
# Bi1
# -0.030000000000043464
# Sc0
# 1.0999999999999606
# Sc1
# -0.18000000000000982
# Ga0
# 0.934999999999997
# Ga1
# 0.3400000000000015
# Nb0
# 0.7299999999999898
# Nb1
# 0.42999999999998073
# Mo0
# 1.2189999999999763
# Mo1
# 0.7549999999999687
# Mn0
# 0.1699999999999946
# Mn1
# 0.4799999999999697
# Mn-1
# 1.9499999999999558
# Zn0
# -0.13000000000002299
# Zn1
# 0.18999999999998163
# Ca0
# 0.039999999999985825
# Ca1
# 0.3099999999999973
# Ca-1
# 1.809999999999994
# Cd0
# -0.020000000000043983
# Cd1
# 0.28599999999999837
# Cd-1
# 1.537999999999976
# Y0
# 1.3599999999999692
# Y1
# -0.2000000000000489
# Ti0
# 0.08999999999997144
# Ti1
# -0.2200000000000194
# Al0
# 1.027999999999972
# Al1
# -0.04700000000000515
# Ag0
# ...

# %%
##Zr_Sn##

nzr=+1
nsn=-1

q=0
Etot=-340.65
E_f0=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*vbm


q=+1
Etot=-343.90
E_f_p1=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Zr')
print(CT)

##As_Sn##

nas=+1
nsn=-1

q=0
Etot=-332.56
E_f0=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm

q=+1
Etot=-334.96
E_f_p1=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT As')
print(CT)


##Sb_Sn##

nsb=+1
nsn=-1

q=0
Etot=-333.16
E_f0=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*vbm


q=+1
Etot=-335.82
E_f_p1=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*vbm+0.08

CT = E_f0 - E_f_p1
print('CT Sb')
print(CT)


##In_Sn##

nin=+1
nsn=-1

q=0
Etot=-331.27
E_f0=Etot-Eclean-nin*u_in-nsn*u_sn+q*vbm


q=+1
Etot=-333.58
E_f_p1=Etot-Eclean-nin*u_in-nsn*u_sn+q*vbm+0.09

CT = E_f0 - E_f_p1
print('CT In')
print(CT)


##Bi_Sn##

nbi=+1
nsn=-1

q=0
Etot=-332.86
E_f0=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*vbm

q=+1
Etot=-335.29
E_f_p1=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*vbm+0.15

CT = E_f0 - E_f_p1
print('CT Bi')
print(CT)


##Sc_Sn##
nsc=+1
nsn=-1

q=0
Etot=-339.17
E_f0=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*vbm


q=+1
Etot=-342.39
E_f_p1=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Sc')
print(CT)


##Ga_Sn##

nga=+1
nsn=-1

q=0
Etot=-331.335
E_f0=Etot-Eclean-nga*u_ga-nsn*u_sn+q*vbm


q=+1
Etot=-333.840
E_f_p1=Etot-Eclean-nga*u_ga-nsn*u_sn+q*vbm+0.09

CT = E_f0 - E_f_p1
print('CT Ga')
print(CT)


##Nb_Sn##

nnb=+1
nsn=-1

q=0
Etot=-342.45
E_f0=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*vbm


q=+1
Etot=-344.69
E_f_p1=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Nb')
print(CT)


##Mo_Sn##

nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm


q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm+0.17

CT = E_f0 - E_f_p1
print('CT Mo')
print(CT)

##Mn_Sn##

nmn=+1
nsn=-1

q=0
Etot=-348.52
E_f0=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm


q=+1
Etot=-350.18
E_f_p1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm+0.15

CT = E_f0 - E_f_p1
print('CT Mn')
print(CT)


##Zn_Sn##

nzn=+1
nsn=-1

q=0
Etot=-330.00
E_f0=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*vbm


q=+1
Etot=-331.63
E_f_p1=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT Zn')
print(CT)


##Ca_Sn##

nca=+1
nsn=-1

q=0
Etot=-333.76
E_f0=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm


q=+1
Etot=-335.46
E_f_p1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm+0.15

CT = E_f0 - E_f_p1
print('CT Ca')
print(CT)


##Cd_Sn##

ncd=+1
nsn=-1

q=0
Etot=-329.790
E_f0=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm


q=+1
Etot=-331.424
E_f_p1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Cd')
print(CT)

##Y_Sn##

ny=+1
nsn=-1

q=0
Etot=-339.68
E_f0=Etot-Eclean-ny*u_y-nsn*u_sn+q*vbm


q=+1
Etot=-343.16
E_f_p1=Etot-Eclean-ny*u_y-nsn*u_sn+q*vbm+0.10

CT = E_f0 - E_f_p1
print('CT Y')
print(CT)


##Ti_Sn##

nti=+1
nsn=-1

q=0
Etot=-341.62
E_f0=Etot-Eclean-nti*u_ti-nsn*u_sn+q*vbm


q=+1
Etot=-343.88
E_f_p1=Etot-Eclean-nti*u_ti-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT Ti')
print(CT)


##Al_Sn##

nal=+1
nsn=-1

q=0
Etot=-332.382
E_f0=Etot-Eclean-nal*u_al-nsn*u_sn+q*vbm


q=+1
Etot=-335.407
E_f_p1=Etot-Eclean-nal*u_al-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT Al')
print(CT)


##Ag_Sn##

nag=+1
nsn=-1

q=0
Etot=-330.702
E_f0=Etot-Eclean-nag*u_ag-nsn*u_sn+q*vbm


q=+1
Etot=-332.036
E_f_p1=Etot-Eclean-nag*u_ag-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Ag')
print(CT)


##Au_Sn##

nau=+1
nsn=-1

q=0
Etot=-330.854
E_f0=Etot-Eclean-nau*u_au-nsn*u_sn+q*vbm


q=+1
Etot=-332.167
E_f_p1=Etot-Eclean-nau*u_au-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Au')
print(CT)


##Mg_Sn##

nmg=+1
nsn=-1

q=0
Etot=-331.488
E_f0=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*vbm


q=+1
Etot=-333.112
E_f_p1=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Mg')
print(CT)


##Cu_Sn##

ncu=+1
nsn=-1

q=0
Etot=-331.287
E_f0=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*vbm


q=+1
Etot=-332.604
E_f_p1=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Cu')
print(CT)


##Ge_Sn##

nge=+1
nsn=-1

q=0
Etot=-333.559
E_f0=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm


q=+1
Etot=-335.332
E_f_p1=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT Ge')
print(CT)


##Pd_Sn##

npd=+1
nsn=-1

q=0
Etot=-334.749
E_f0=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm


q=+1
Etot=-335.812
E_f_p1=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT Pd')
print(CT)


##W_Sn##

nw=+1
nsn=-1

q=0
Etot=-342.49
E_f0=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm


q=+1
Etot=-344.67
E_f_p1=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT W')
print(CT)


##V_Sn##

nv=+1
nsn=-1

q=0
Etot=-344.61
E_f0=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm


q=+1
Etot=-346.24
E_f_p1=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm+0.13

CT = E_f0 - E_f_p1
print('CT V')
print(CT)


##Cr_Sn##

ncr=+1
nsn=-1

q=0
Etot=-346.693
E_f0=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*vbm

q=+1
Etot=-348.333
E_f_p1=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*vbm+0.12

CT = E_f0 - E_f_p1
print('CT Cr')
print(CT)


##Mo_Sn##

nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm


q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm+0.17

CT = E_f0 - E_f_p1
print('CT Mo')
print(CT)
# Out:
# CT Zr
# 1.31
# CT As
# 0.4599999999999772
# CT Sb
# 0.759999999999968
# CT In
# 0.40000000000000224
# CT Bi
# 0.46000000000000674
# CT Sc
# 1.2799999999999705
# CT Ga
# 0.5949999999999954
# CT Nb
# 0.30000000000000904
# CT Mo
# 0.46400000000000763
# CT Mn
# -0.3099999999999751
# CT Zn
# -0.3200000000000046
# CT Ca
# -0.27000000000001145
# CT Cd
# -0.30600000000004235
# CT Y
# 1.560000000000018
# CT Ti
# 0.30999999999999084
# CT Al
# 1.074999999999977
# CT Ag
# -0.6059999999999969
# CT Au
# -0.6270000000000119
# CT Mg
# -0.3159999999999764
# CT Cu
# -0.6229999999999928
# CT Ge
# -0.17700000000003235
# CT Pd
# -0.8870000000000119
# CT W
# 0.23000000000000664
# CT V
# -0.3200000000000046
# CT Cr
# -0.29999999999995686
# CT Mo
# 0.46400000000000763

# %% [markdown]
# # I-poor condition
# ## Sn-site I-poor condition

# %%
u_bi = -5.75
u_sb = -6.52
u_as = -5.34
u_sc = -12.73
u_ti = -13.98
u_y  = -13.50
u_zr = -14.42
u_al = -5.87
u_ca = -6.55
u_ga = -4.73
u_in = -4.22
u_cd = -2.52
u_cu = -4.09
u_mo = -16.05
u_mn = -21.44
u_nb = -15.06
u_zn = -2.62
u_w  = -16.19
u_ag = -3.84
u_au = -3.45
u_v  = -17.37
u_cr = -19.23
u_mg = -4.18
u_pd = -7.52
u_ge = -6.24

u_sn = -5.48
u_cs = -4.18

vbm = 1.82
Eclean = -332.65
fermi=np.arange(0,1.6728,0.01)

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)
ax=fig.add_subplot(1,1,1)

##Zr_Sn##
nzr=+1
nsn=-1

q=0
Etot=-340.65
E_f0=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.90
E_f_p1=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#E7CBCB', linewidth=3, label='Zr_Sn')

##As_Sn##
nas=+1
nsn=-1

q=0
Etot=-332.56
E_f0=Etot-Eclean-nas*u_as-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-334.96
E_f_p1=Etot-Eclean-nas*u_as-nsn*u_sn+q*fermi+q*vbm+0.12

q=+2
Etot=-336.75
E_f_p2=Etot-Eclean-nas*u_as-nsn*u_sn+q*fermi+q*vbm+0.53

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#F1C27B', linewidth=3, label='As_Sn')

##Sb_Sn##
nsb=+1
nsn=-1

q=0
Etot=-333.16
E_f0=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.82
E_f_p1=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*fermi+q*vbm+0.08

q=+2
Etot=-337.01
E_f_p2=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*fermi+q*vbm+0.54

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FFEADD', linewidth=3, label='Sb_Sn')

##In_Sn##
nin=+1
nsn=-1

q=0
Etot=-331.27
E_f0=Etot-Eclean-nin*u_in-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-333.58
E_f_p1=Etot-Eclean-nin*u_in-nsn*u_sn+q*fermi+q*vbm+0.09

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='In_Sn')

##Bi_Sn##
nbi=+1
nsn=-1

q=0
Etot=-332.86
E_f0=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.29
E_f_p1=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*fermi+q*vbm+0.15

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FCAEAE', linewidth=3, label='Bi_Sn')

##Sc_Sn##
nsc=+1
nsn=-1

q=0
Etot=-339.17
E_f0=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-342.39
E_f_p1=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#643843', linewidth=3, label='Sc_Sn')

##Ga_Sn##
nga=+1
nsn=-1

q=0
Etot=-331.335
E_f0=Etot-Eclean-nga*u_ga-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-333.840
E_f_p1=Etot-Eclean-nga*u_ga-nsn*u_sn+q*fermi+q*vbm+0.09

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ga_Sn')

##Nb_Sn##
nnb=+1
nsn=-1

q=0
Etot=-342.45
E_f0=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-344.69
E_f_p1=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Nb_Sn')

##Mo_Sn##
nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*fermi+q*vbm+0.17

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mo_Sn')

##Mn_Sn##
nmn=+1
nsn=-1

q=0
Etot=-348.52
E_f0=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-350.18
E_f_p1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*fermi+q*vbm+0.15

q=-1
Etot=-345.04
E_f_n1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*fermi+q*vbm+0.11

arr=[E_f_p1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mn_Sn')

##Zn_Sn##
nzn=+1
nsn=-1

q=0
Etot=-330.00
E_f0=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-331.63
E_f_p1=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Zn_Sn')

##Ca_Sn##
nca=+1
nsn=-1

q=0
Etot=-333.76
E_f0=Etot-Eclean-nca*u_ca-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.46
E_f_p1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*fermi+q*vbm+0.15

q=-1
Etot=-330.27
E_f_n1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*fermi+q*vbm+0.10

arr=[E_f_p1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ca_Sn')

##Cd_Sn##
ncd=+1
nsn=-1

q=0
Etot=-329.790
E_f0=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-331.424
E_f_p1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*fermi+q*vbm+0.12

q=-1
Etot=-326.512
E_f_n1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*fermi+q*vbm+0.10

arr=[E_f_p1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cd_Sn')

##Y_Sn##
ny=+1
nsn=-1

q=0
Etot=-339.68
E_f0=Etot-Eclean-ny*u_y-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.16
E_f_p1=Etot-Eclean-ny*u_y-nsn*u_sn+q*fermi+q*vbm+0.10

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#E893CF', linewidth=3, label='Y_Sn')

##Ti_Sn##
nti=+1
nsn=-1

q=0
Etot=-341.62
E_f0=Etot-Eclean-nti*u_ti-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.88
E_f_p1=Etot-Eclean-nti*u_ti-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#C88EA7', linewidth=3, label='Ti_Sn')

##Al_Sn##
nal=+1
nsn=-1

q=0
Etot=-332.382
E_f0=Etot-Eclean-nal*u_al-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.407
E_f_p1=Etot-Eclean-nal*u_al-nsn*u_sn+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Al_Sn')

##Ag_Sn##
nag=+1
nsn=-1

q=0
Etot=-330.702
E_f0=Etot-Eclean-nag*u_ag-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-332.036
E_f_p1=Etot-Eclean-nag*u_ag-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ag_Sn')

##Au_Sn##
nau=+1
nsn=-1

q=0
Etot=-330.854
E_f0=Etot-Eclean-nau*u_au-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-332.167
E_f_p1=Etot-Eclean-nau*u_au-nsn*u_sn+q*fermi+q*vbm+0.11

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Au_Sn')

##Mg_Sn##
nmg=+1
nsn=-1

q=0
Etot=-331.488
E_f0=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-333.112
E_f_p1=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mg_Sn')

##Cu_Sn##
ncu=+1
nsn=-1

q=0
Etot=-331.287
E_f0=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-332.604
E_f_p1=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cu_Sn')

##Ge_Sn##
nge=+1
nsn=-1

q=0
Etot=-333.559
E_f0=Etot-Eclean-nge*u_ge-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.332
E_f_p1=Etot-Eclean-nge*u_ge-nsn*u_sn+q*fermi+q*vbm+0.13

q=+2
Etot=-336.725
E_f_p2=Etot-Eclean-nge*u_ge-nsn*u_sn+q*fermi+q*vbm+0.57

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ge_Sn')

##Pd_Sn##
npd=+1
nsn=-1

q=0
Etot=-334.749
E_f0=Etot-Eclean-npd*u_pd-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-335.812
E_f_p1=Etot-Eclean-npd*u_pd-nsn*u_sn+q*fermi+q*vbm+0.11

q=+2
Etot=-336.990
E_f_p2=Etot-Eclean-npd*u_pd-nsn*u_sn+q*fermi+q*vbm+0.61

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Pd_Sn')

##W_Sn##
nw=+1
nsn=-1

q=0
Etot=-342.49
E_f0=Etot-Eclean-nw*u_w-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-344.67
E_f_p1=Etot-Eclean-nw*u_w-nsn*u_sn+q*fermi+q*vbm+0.17

q=+2
Etot=-346.26
E_f_p2=Etot-Eclean-nw*u_w-nsn*u_sn+q*fermi+q*vbm+0.52

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='W_Sn')

##V_Sn##
nv=+1
nsn=-1

q=0
Etot=-344.61
E_f0=Etot-Eclean-nv*u_v-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-346.24
E_f_p1=Etot-Eclean-nv*u_v-nsn*u_sn+q*fermi+q*vbm+0.14

q=+2
Etot=-347.37
E_f_p2=Etot-Eclean-nv*u_v-nsn*u_sn+q*fermi+q*vbm+0.49

arr=[E_f_p1, E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='V_Sn')

##Cr_Sn##
ncr=+1
nsn=-1

q=0
Etot=-346.693
E_f0=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-348.333
E_f_p1=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cr_Sn')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)
ax.set_xlim([0, 1.35])
ax.set_ylim([-1.1, 2.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.32, 0.4))
plt.yticks(np.arange(-1.0, 2.05, 0.5))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=5, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.01))
#plt.savefig('I-poor-Sn-doping-site.jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
##Zr_Sn##

nzr=+1
nsn=-1

q=0
Etot=-340.65
E_f0=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*vbm
print('Zr0')
print(E_f0)

q=+1
Etot=-343.90
E_f_p1=Etot-Eclean-nzr*u_zr-nsn*u_sn+q*vbm+0.12
print('Zr1')
print(E_f_p1)

##As_Sn##

nas=+1
nsn=-1

q=0
Etot=-332.56
E_f0=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm
print('As0')
print(E_f0)

q=+1
Etot=-334.96
E_f_p1=Etot-Eclean-nas*u_as-nsn*u_sn+q*vbm+0.12
print('As1')
print(E_f_p1)


##Sb_Sn##

nsb=+1
nsn=-1

q=0
Etot=-333.16
E_f0=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*vbm
print('Sb0')
print(E_f0)

q=+1
Etot=-335.82
E_f_p1=Etot-Eclean-nsb*u_sb-nsn*u_sn+q*vbm+0.08
print('Sb1')
print(E_f_p1)


##In_Sn##

nin=+1
nsn=-1

q=0
Etot=-331.27
E_f0=Etot-Eclean-nin*u_in-nsn*u_sn+q*vbm
print('In0')
print(E_f0)

q=+1
Etot=-333.58
E_f_p1=Etot-Eclean-nin*u_in-nsn*u_sn+q*vbm+0.09
print('In0')
print(E_f_p1)


##Bi_Sn##

nbi=+1
nsn=-1

q=0
Etot=-332.86
E_f0=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*vbm
print('Bi0')
print(E_f0)

q=+1
Etot=-335.29
E_f_p1=Etot-Eclean-nbi*u_bi-nsn*u_sn+q*vbm+0.15
print('Bi1')
print(E_f_p1)


##Sc_Sn##
nsc=+1
nsn=-1

q=0
Etot=-339.17
E_f0=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*vbm
print('Sc0')
print(E_f0)

q=+1
Etot=-342.39
E_f_p1=Etot-Eclean-nsc*u_sc-nsn*u_sn+q*vbm+0.12
print('Sc1')
print(E_f_p1)


##Ga_Sn##

nga=+1
nsn=-1

q=0
Etot=-331.335
E_f0=Etot-Eclean-nga*u_ga-nsn*u_sn+q*vbm
print('Ga0')
print(E_f0)

q=+1
Etot=-333.840
E_f_p1=Etot-Eclean-nga*u_ga-nsn*u_sn+q*vbm+0.09
print('Ga1')
print(E_f_p1)


##Nb_Sn##

nnb=+1
nsn=-1

q=0
Etot=-342.45
E_f0=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*vbm
print('Nb0')
print(E_f0)

q=+1
Etot=-344.69
E_f_p1=Etot-Eclean-nnb*u_nb-nsn*u_sn+q*vbm+0.12
print('Nb1')
print(E_f_p1)


##Mo_Sn##

nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm
print('Mo0')
print(E_f0)

q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm+0.17
print('Mo1')
print(E_f_p1)

##Mn_Sn##

nmn=+1
nsn=-1

q=0
Etot=-348.52
E_f0=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm
print('Mn0')
print(E_f0)

q=+1
Etot=-350.18
E_f_p1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm+0.15
print('Mn1')
print(E_f_p1)

q=-1
Etot=-345.04
E_f_n1=Etot-Eclean-nmn*u_mn-nsn*u_sn+q*vbm+0.12
print('Mn-1')
print(E_f_n1)


##Zn_Sn##

nzn=+1
nsn=-1

q=0
Etot=-330.00
E_f0=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*vbm
print('Zn0')
print(E_f0)

q=+1
Etot=-331.63
E_f_p1=Etot-Eclean-nzn*u_zn-nsn*u_sn+q*vbm+0.13
print('Zn1')
print(E_f_p1)


##Ca_Sn##

nca=+1
nsn=-1

q=0
Etot=-333.76
E_f0=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm
print('Ca0')
print(E_f0)

q=+1
Etot=-335.46
E_f_p1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm+0.15
print('Ca1')
print(E_f_p1)

q=-1
Etot=-330.27
E_f_n1=Etot-Eclean-nca*u_ca-nsn*u_sn+q*vbm+0.1
print('Ca-1')
print(E_f_n1)


##Cd_Sn##

ncd=+1
nsn=-1

q=0
Etot=-329.790
E_f0=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm
print('Cd0')
print(E_f0)

q=+1
Etot=-331.424
E_f_p1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm+0.12
print('Cd1')
print(E_f_p1)

q=-1
Etot=-326.512
E_f_n1=Etot-Eclean-ncd*u_cd-nsn*u_sn+q*vbm+0.1
print('Cd-1')
print(E_f_n1)

##Y_Sn##

ny=+1
nsn=-1

q=0
Etot=-339.68
E_f0=Etot-Eclean-ny*u_y-nsn*u_sn+q*vbm
print('Y0')
print(E_f0)

q=+1
Etot=-343.16
E_f_p1=Etot-Eclean-ny*u_y-nsn*u_sn+q*vbm+0.10
print('Y1')
print(E_f_p1)


##Ti_Sn##

nti=+1
nsn=-1

q=0
Etot=-341.62
E_f0=Etot-Eclean-nti*u_ti-nsn*u_sn+q*vbm
print('Ti0')
print(E_f0)

q=+1
Etot=-343.88
E_f_p1=Etot-Eclean-nti*u_ti-nsn*u_sn+q*vbm+0.13
print('Ti1')
print(E_f_p1)


##Al_Sn##

nal=+1
nsn=-1

q=0
Etot=-332.382
E_f0=Etot-Eclean-nal*u_al-nsn*u_sn+q*vbm
print('Al0')
print(E_f0)

q=+1
Etot=-335.407
E_f_p1=Etot-Eclean-nal*u_al-nsn*u_sn+q*vbm+0.13
print('Al1')
print(E_f_p1)


##Ag_Sn##

nag=+1
nsn=-1

q=0
Etot=-330.702
E_f0=Etot-Eclean-nag*u_ag-nsn*u_sn+q*vbm
print('Ag0')
print(E_f0)

q=+1
Etot=-332.036
E_f_p1=Etot-Eclean-nag*u_ag-nsn*u_sn+q*vbm+0.12
print('Ag1')
print(E_f_p1)


##Au_Sn##

nau=+1
nsn=-1

q=0
Etot=-330.854
E_f0=Etot-Eclean-nau*u_au-nsn*u_sn+q*vbm
print('Au0')
print(E_f0)

q=+1
Etot=-332.167
E_f_p1=Etot-Eclean-nau*u_au-nsn*u_sn+q*vbm+0.12
print('Au1')
print(E_f_p1)


##Mg_Sn##

nmg=+1
nsn=-1

q=0
Etot=-331.488
E_f0=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*vbm
print('Mg0')
print(E_f0)

q=+1
Etot=-333.112
E_f_p1=Etot-Eclean-nmg*u_mg-nsn*u_sn+q*vbm+0.12
print('Mg1')
print(E_f_p1)


##Cu_Sn##

ncu=+1
nsn=-1

q=0
Etot=-331.287
E_f0=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*vbm
print('Cu0')
print(E_f0)

q=+1
Etot=-332.604
E_f_p1=Etot-Eclean-ncu*u_cu-nsn*u_sn+q*vbm+0.12
print('Cu1')
print(E_f_p1)


##Ge_Sn##

nge=+1
nsn=-1

q=0
Etot=-333.559
E_f0=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm
print('Ge0')
print(E_f0)

q=+1
Etot=-335.332
E_f_p1=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm+0.13
print('Ge1')
print(E_f_p1)

q=+2
Etot=-336.725
E_f_p2=Etot-Eclean-nge*u_ge-nsn*u_sn+q*vbm+0.57
print('Ge2')
print(E_f_p2)

##Pd_Sn##

npd=+1
nsn=-1

q=0
Etot=-334.749
E_f0=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm
print('Pd0')
print(E_f0)

q=+1
Etot=-335.812
E_f_p1=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm+0.13
print('Pd1')
print(E_f_p1)

q=+2
Etot=-336.990
E_f_p2=Etot-Eclean-npd*u_pd-nsn*u_sn+q*vbm+0.57
print('Pd2')
print(E_f_p2)


##W_Sn##

nw=+1
nsn=-1

q=0
Etot=-342.49
E_f0=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm
print('W0')
print(E_f0)

q=+1
Etot=-344.67
E_f_p1=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm+0.13
print('W')
print(E_f_p1)

q=+2
Etot=-346.26
E_f_p2=Etot-Eclean-nw*u_w-nsn*u_sn+q*vbm+0.57
print('W2')
print(E_f_p2)


##V_Sn##

nv=+1
nsn=-1

q=0
Etot=-344.61
E_f0=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm
print('V0')
print(E_f0)

q=+1
Etot=-346.24
E_f_p1=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm+0.13
print('V1')
print(E_f_p1)

q=+2
Etot=-347.37
E_f_p2=Etot-Eclean-nv*u_v-nsn*u_sn+q*vbm+0.57
print('V2')
print(E_f_p2)


##Cr_Sn##

ncr=+1
nsn=-1

q=0
Etot=-346.693
E_f0=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*vbm
print('Cr0')
print(E_f0)

q=+1
Etot=-348.333
E_f_p1=Etot-Eclean-ncr*u_cr-nsn*u_sn+q*vbm+0.12
print('Cr1')
print(E_f_p1)

##Mo_Sn##

nmo=+1
nsn=-1

q=0
Etot=-342.661
E_f0=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm
print('Mo0')
print(E_f0)

q=+1
Etot=-345.115
E_f_p1=Etot-Eclean-nmo*u_mo-nsn*u_sn+q*vbm+0.17
print('Mo1')
print(E_f_p1)
# Out:
# Zr0
# 0.9399999999999995
# Zr1
# -0.37000000000000044
# As0
# -0.05000000000002558
# As1
# -0.5100000000000028
# Sb0
# 0.5299999999999514
# Sb1
# -0.2300000000000167
# In0
# 0.11999999999999478
# In0
# -0.28000000000000747
# Bi0
# 0.059999999999963194
# Bi1
# -0.40000000000004354
# Sc0
# 0.7299999999999613
# Sc1
# -0.550000000000009
# Ga0
# 0.5649999999999977
# Ga1
# -0.029999999999997667
# Nb0
# -0.2200000000000113
# Nb1
# -0.5200000000000203
# Mo0
# 0.5589999999999762
# Mo1
# 0.09499999999996853
# Mn0
# 0.0899999999999963
# Mn1
# 0.3999999999999714
# Mn-1
# 1.8699999999999575
# Zn0
# -0.21000000000002306
# Zn1
# 0.10999999999998156
# Ca0
# -0.040000000000014246
# Ca1
# 0.22999999999999718
# Ca-1
# 1.7299999999999958
# Cd0
# -0.10000000000004405
# Cd1
# 0.20599999999999874
# Cd-1
# 1.457999999999976
# Y0
# 0.98999999999997
# Y1
# -0.5700000000000481
# Ti0
# -0.4700000000000273
# Ti1
# -0.7800000000000181
# Al0
# 0.6579999999999719
# Al1
# -0.41700000000000526
# Ag0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

# %% [markdown]
# # Defect formation energy of CsSnI3
# ## I-rich condition

# %%
cssni3 = -83.149965/4
i3 = -5.6350629/2*3
cs = -5.373/4
sn = -43.835/8
H_f_cssni3 = cssni3-i3-sn-cs
print('cssni3 formation enthalpy')
print(H_f_cssni3)
# Out:
# cssni3 formation enthalpy
# -5.512271899999998

# %%
#I-rich condition:
#At point A = (-0.50, -0.61)

du_sn = -0.50
du_i  = -0.605
du_cs = -5.5123-du_sn-3*du_i

u_sn = sn+du_sn
u_i  = (i3/3)+du_i
u_cs = cs+du_cs

u_ba = -7.57
u_y  = -14.40

vbm = 1.82
Eclean = -332.65
fermi=np.arange(0,1.6728,0.01)

print('du_Sn')
print(du_sn)

print('du_I')
print(du_i)

print('du_Cs')
print(du_cs)

print('I-rich condition')
print('u_Sn')
print(u_sn)

print('u_I')
print(u_i)

print('u_Cs')
print(u_cs)
# Out:
# du_Sn
# -0.5
# du_I
# -0.605
# du_Cs
# -3.1973
# I-rich condition
# u_Sn
# -5.979375
# u_I
# -3.42253145
# u_Cs
# -4.54055

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)
ax=fig.add_subplot(1,1,1)

## V_Cs
ncs=-1

q=0
Etot=-327.55
E_f0=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-326.69
E_f_1=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#D14D72', linewidth=3, label='VCs')

## V_Sn
nsn=-1

q=0
Etot=-325.81
E_f0=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm

q=-1
Etot=-324.23
E_f_1=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.07

q=-2
Etot=-323.59
E_f_2=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.46

arr=[E_f_1,E_f_2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FFABAB', linewidth=3, label='VSn')

## V_I
ni=-1

q=0
Etot=-328.05
E_f0=Etot-Eclean-ni*u_i+q*fermi+q*vbm

q=+1
Etot=-331.03
E_f1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.15

q=-1
Etot=-325.50
E_f_n1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.10

arr=[E_f1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FDE5EC', linewidth=3, label='VI')

## Csi_Converged ##
ncs=1

q=0
Etot=-333.11
E_f0=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-337.84
E_f1=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm+0.16

arr=[E_f1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#61876E', linewidth=3, label='Csi')

## Sni
nsn=1

q=0
Etot=-336.53
E_f0=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-339.01
E_f1=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.18

q=+2
Etot=-340.97
E_f2=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.58

arr=[E_f1,E_f2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#A6BB8D', linewidth=3, label='Sni')

## Ii
ni=1

q=0
Etot=-335.74
E_f0=Etot-Eclean-ni*u_i+q*fermi+q*vbm

q=-1
Etot=-333.87
E_f1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.15

q=+1
Etot=-335.04
E_f_p1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.16

arr=[E_f1,E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#EAE7B1', linewidth=3, label='Ii')

## Sn_Cs
nsn=+1
ncs=-1

q=0
Etot=-329.59
E_f0=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-326.80
E_f_n1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.17

q=+1
Etot=-335.95
E_f_p1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.1786860

q=+2
Etot=-334.67
E_f_p2=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.52

arr=[E_f_n1,E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#37306B', linewidth=3, label='Sn_Cs')

## I_Cs
ni=+1
ncs=-1

q=0
Etot=-330.79
E_f0=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-329.32
E_f_n1=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.16

q=-2
Etot=-327.57
E_f_n2=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.54

arr=[E_f_n1, E_f_n2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#655DBB', linewidth=3, label='I_Cs')

## Cs_Sn
ncs=+1
nsn=-1

q=0
Etot=-328.88
E_f0=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-328.86
E_f_n1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.17

q=-2
Etot=-324.04
E_f_n2=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.54

q=+1
Etot=-330.62
E_f_p1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_n1,E_f_n2,E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#BFACE2', linewidth=3, label='Cs_Sn')

## I_Sn
ni=+1
nsn=-1

q=0
Etot=-328.17
E_f0=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm

q=-1
Etot=-327.54
E_f_n1=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.12

q=-2
Etot=-325.37
E_f_n2=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.51

arr=[E_f_n1,E_f_n2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#AA77FF', linewidth=3, label='I_Sn')

## Cs_I
ni=-1
ncs=+1

q=0
Etot=-329.33
E_f0=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-333.12
E_f_p1=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.17

q=+2
Etot=-336.43
E_f_p2=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.56

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#97DEFF', linewidth=3, label='Cs_I')

## Sn_I
ni=-1
nsn=+1

q=0
Etot=-331.86
E_f0=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm

q=+1
Etot=-335.17
E_f_p1=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.10

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#C9EEFF', linewidth=3, label='Sn_I')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)
ax.set_xlim([0, 1.4])
ax.set_ylim([-3.1, 4.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.35, 0.4))
plt.yticks(np.arange(-3, 4.1, 1))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=3, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.01))
#plt.savefig('Ef_CsSnI3_Irich_100924(kpoint112).jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## I-poor condition

# %%
#I-poor condition:
#At point A = (0.0, -0.89)
du_sn = 0.0
du_i  = -0.89
du_cs = -5.5123-du_sn-3*du_i

u_sn = sn+du_sn
u_i  = (i3/3)+du_i
u_cs = cs+du_cs

u_ba = -6.96
u_y  = -13.53

vbm  = 1.82
Eclean = -332.65
fermi=np.arange(0,1.6285,0.01)

print('du_Sn')
print(du_sn)

print('du_I')
print(du_i)

print('du_Cs')
print(du_cs)

print('I-poor condition')
print('u_Sn')
print(u_sn)

print('u_I')
print(u_i)

print('u_Cs')
print(u_cs)
# Out:
# du_Sn
# 0.0
# du_I
# -0.89
# du_Cs
# -2.8423
# I-poor condition
# u_Sn
# -5.479375
# u_I
# -3.7075314500000003
# u_Cs
# -4.18555

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)
ax=fig.add_subplot(1,1,1)

## V_Cs
ncs=-1

q=0
Etot=-327.55
E_f0=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-326.69
E_f_1=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#D14D72', linewidth=3, label='VCs')

## V_Sn
nsn=-1

q=0
Etot=-325.81
E_f0=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm

q=-1
Etot=-324.23
E_f_1=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.07

q=-2
Etot=-323.59
E_f_2=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.46

arr=[E_f_1,E_f_2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FFABAB', linewidth=3, label='VSn')

## V_I
ni=-1

q=0
Etot=-328.05
E_f0=Etot-Eclean-ni*u_i+q*fermi+q*vbm

q=+1
Etot=-331.03
E_f1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.15

q=-1
Etot=-325.50
E_f_n1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.10

arr=[E_f1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FDE5EC', linewidth=3, label='VI')

## Csi_Converged ##
ncs=1

q=0
Etot=-333.11
E_f0=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-337.84
E_f1=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm+0.16

arr=[E_f1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#61876E', linewidth=3, label='Csi')

## Sni
nsn=1

q=0
Etot=-336.53
E_f0=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-339.01
E_f1=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.18

q=+2
Etot=-340.97
E_f2=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.58

arr=[E_f1,E_f2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#A6BB8D', linewidth=3, label='Sni')

## Ii
ni=1

q=0
Etot=-335.74
E_f0=Etot-Eclean-ni*u_i+q*fermi+q*vbm

q=-1
Etot=-333.87
E_f1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.15

q=+1
Etot=-335.04
E_f_p1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.16

arr=[E_f1,E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#EAE7B1', linewidth=3, label='Ii')

## Sn_Cs
nsn=+1
ncs=-1

q=0
Etot=-329.59
E_f0=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-326.80
E_f_n1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.17

q=+1
Etot=-335.95
E_f_p1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.1786860

q=+2
Etot=-334.67
E_f_p2=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.52

arr=[E_f_n1,E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#37306B', linewidth=3, label='Sn_Cs')

## I_Cs
ni=+1
ncs=-1

q=0
Etot=-330.79
E_f0=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-329.32
E_f_n1=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.16

q=-2
Etot=-327.57
E_f_n2=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.54

arr=[E_f_n1, E_f_n2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#655DBB', linewidth=3, label='I_Cs')

## Cs_Sn
ncs=+1
nsn=-1

q=0
Etot=-328.88
E_f0=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm

q=-1
Etot=-328.86
E_f_n1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.17

q=-2
Etot=-324.04
E_f_n2=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.54

q=+1
Etot=-330.62
E_f_p1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_n1,E_f_n2,E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#BFACE2', linewidth=3, label='Cs_Sn')

## I_Sn
ni=+1
nsn=-1

q=0
Etot=-328.17
E_f0=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm

q=-1
Etot=-327.54
E_f_n1=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.12

q=-2
Etot=-325.37
E_f_n2=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.51

arr=[E_f_n1,E_f_n2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#AA77FF', linewidth=3, label='I_Sn')

## Cs_I
ni=-1
ncs=+1

q=0
Etot=-329.33
E_f0=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-333.12
E_f_p1=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.17

q=+2
Etot=-336.43
E_f_p2=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.56

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#97DEFF', linewidth=3, label='Cs_I')

## Sn_I
ni=-1
nsn=+1

q=0
Etot=-331.86
E_f0=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm

q=+1
Etot=-335.17
E_f_p1=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.10

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#C9EEFF', linewidth=3, label='Sn_I')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)
ax.set_xlim([0, 1.4])
ax.set_ylim([-3.1, 4.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.35, 0.4))
plt.yticks(np.arange(-3, 4.1, 1))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=3, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.01))
#plt.savefig('Ef_CsSnI3_Ipoor_100924(kpoint112).jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Ef_pin_of_intrinsic_defect
q=+1
Etot=-331.03
vi=-331.03+u_i+vbm+0.15
sncs=-335.95-u_sn+u_cs+vbm+0.1786860
vcs=-326.69+u_cs-vbm+0.13

qtr=(vi-vcs)/-2
print(qtr)
# Out:
# 0.10099072500000261

# %%
vcs=-326.69+u_cs-vbm+0.129805
ysn=-343.16-u_y+u_sn+vbm+0.100967

qtr=(ysn-vcs)/-2
print(qtr)
# Out:
# 0.31133150000002274

# %%
vcs=-326.69+u_cs-vbm+0.129805
bacs=-337.80-u_ba+u_cs+vbm+0.118351

qtr=(bacs-vcs)/-2
print(qtr)
# Out:
# 0.2607270000000028

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)

ax=fig.add_subplot(1,1,1)

###############################################  Vacancies  ##################################################

## V_Cs_Converged ##
ncs=-1

q=0
Etot=-327.55
E_f0=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='blue', linestyle='--', linewidth=3)

q=-1
Etot=-326.69
E_f_1=Etot-Eclean-ncs*u_cs+q*fermi+q*vbm+0.129805

arr=[E_f_1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#D14D72', linewidth=3, label='VCs')


## V_Sn_Converged ##
nsn=-1

q=0
Etot=-325.81
E_f0=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='blue', linestyle='--', linewidth=3)

q=-1
Etot=-324.23
E_f_1=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.0729332

q=-2
Etot=-323.59
E_f_2=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.463707

arr=[E_f_1,E_f_2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FFABAB', linewidth=3, label='VSn')


## V_I_Converged ##

ni=-1

q=0
Etot=-328.05
E_f0=Etot-Eclean-ni*u_i+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='pink', linestyle='--', linewidth=3)

q=+1
Etot=-331.03
E_f1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.1546470

q=-1
Etot=-325.50
E_f_n1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.1016670

arr=[E_f1, E_f_n1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FDE5EC', linewidth=3, label='VI')


#################################################  Insertion  #######################################################

## Sni_Converged ##
nsn=1

q=0
Etot=-336.53
E_f0=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='#FFA500', linestyle='--', linewidth=3)

q=+1
Etot=-339.01
E_f1=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.1781670

q=+2
Etot=-340.97
E_f2=Etot-Eclean-nsn*u_sn+q*fermi+q*vbm+0.5800230

arr=[E_f1,E_f2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#A6BB8D', linewidth=3, label='Sni')


## Ii_Converged ##
ni=1

q=0
Etot=-335.74
E_f0=Etot-Eclean-ni*u_i+q*fermi+q*vbm

q=-1
Etot=-333.87
E_f1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.1453180

q=+1
Etot=-335.04
E_f_p1=Etot-Eclean-ni*u_i+q*fermi+q*vbm+0.1616670

arr=[E_f1,E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#EAE7B1', linewidth=3, label='Ii')

#################################################  Antisite  #######################################################

## Sn_Cs_Converged ##

nsn=+1
ncs=-1

q=0
Etot=-329.59
E_f0=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='blue', linestyle='--', linewidth=3)

q=-1
Etot=-326.80
E_f_n1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.169074

q=+1
Etot=-335.95
E_f_p1=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.1786860

q=+2
Etot=-334.67
E_f_p2=Etot-Eclean-nsn*u_sn-ncs*u_cs+q*fermi+q*vbm+0.2267070

arr=[E_f_n1,E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#37306B', linewidth=3, label='Sn_Cs')


## I_Cs_Converged ##

ni=+1
ncs=-1

q=0
Etot=-330.79
E_f0=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='blue', linestyle='--', linewidth=3)

q=-1
Etot=-329.32
E_f_n1=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.1635670

q=-2
Etot=-327.57
E_f_n2=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.5424670

arr=[E_f_n1, E_f_n2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#655DBB', linewidth=3, label='I_Cs')


## I_Sn_Converged ##

ni=+1
nsn=-1

q=0
Etot=-328.17
E_f0=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='blue', linestyle='--', linewidth=3)

q=-1
Etot=-327.54
E_f_n1=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.1228670

q=-2
Etot=-325.37
E_f_n2=Etot-Eclean-nsn*u_sn-ni*u_i+q*fermi+q*vbm+0.5130470

arr=[E_f_n1,E_f_n2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#AA77FF', linewidth=3, label='I_Sn')


## Cs_I_Converged ##

ni=-1
ncs=+1

q=0
Etot=-329.33
E_f0=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm
#plt.plot(fermi, E_f0, color='blue', linestyle='--', linewidth=3)

q=+1
Etot=-333.12
E_f_p1=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.1682850

q=+2
Etot=-336.43
E_f_p2=Etot-Eclean-ni*u_i-ncs*u_cs+q*fermi+q*vbm+0.5612670

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#97DEFF', linewidth=3, label='Cs_I')


## Y_Sn_Converged ##

ny=+1
nsn=-1

q=0
Etot=-337.86
E_f0=Etot-Eclean-ny*u_y-nsn*u_sn+q*fermi+q*vbm

q=+1
Etot=-343.16
E_f_p1=Etot-Eclean-ny*u_y-nsn*u_sn+q*fermi+q*vbm+0.100967

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#E893CF', linewidth=3, label='Y_Sn')

##Ba_Cs##

nba=+1
ncs=-1

q=0
Etot=-332.88
E_f0=Etot-Eclean-nba*u_ba-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-337.80
E_f_p1=Etot-Eclean-nba*u_ba-ncs*u_cs+q*fermi+q*vbm+0.118351


arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, color='#FF8989', linewidth=3, label='Ba_Cs')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)
ax.set_xlim([0, 1.4])
ax.set_ylim([-3.1, 4.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.35, 0.4))
plt.yticks(np.arange(-3, 4.1, 1))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=3, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
#plt.legend(loc='lower left')
plt.savefig('Ef_CsSnI3_Ipoor_072224(kpoint112).jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

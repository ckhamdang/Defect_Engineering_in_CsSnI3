# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)

# %% [markdown]
# # I-rich condition

# %% [markdown]
# ## Cs-site I-rich condition

# %%
u_ca = -7.13
u_ba = -7.54
u_sr = -6.80
u_y  = -14.37
u_cu = -4.67
u_mo = -17.21
u_cd = -3.10
u_zr = -15.58
u_al = -6.74
u_ga = -5.60
u_in = -5.09
u_sc = -13.60
u_zn = -3.20
u_w  = -17.35
u_nb = -16.51

u_sn = -5.98
u_cs = -4.54

vbm = 1.82
Eclean = -332.65
fermi=np.arange(0,1.6728,0.01)

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)
ax=fig.add_subplot(1,1,1)

##Ca_Cs##
nca=+1
ncs=-1

q=0
Etot=-333.00
E_f0=Etot-Eclean-nca*u_ca-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-336.52
E_f_p1=Etot-Eclean-nca*u_ca-ncs*u_cs+q*fermi+q*vbm+0.11

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ca_Cs')

##Ba_Cs##
nba=+1
ncs=-1

q=0
Etot=-332.89
E_f0=Etot-Eclean-nba*u_ba-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-337.80
E_f_p1=Etot-Eclean-nba*u_ba-ncs*u_cs+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ba_Cs')

##Sr_Cs##
nsr=+1
ncs=-1

q=0
Etot=-333.46
E_f0=Etot-Eclean-nsr*u_sr-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-336.98
E_f_p1=Etot-Eclean-nsr*u_sr-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Sr_Cs')

##Y_Cs##
ny=+1
ncs=-1

q=0
Etot=-338.75
E_f0=Etot-Eclean-ny*u_y-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-342.69
E_f_p1=Etot-Eclean-ny*u_y-ncs*u_cs+q*fermi+q*vbm+0.08

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Y_Cs')

##Cu_Cs##
ncu=+1
ncs=-1

q=0
Etot=-330.25
E_f0=Etot-Eclean-ncu*u_cu-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-332.04
E_f_p1=Etot-Eclean-ncu*u_cu-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cu_Cs')

##Mo_Cs##
nmo=+1
ncs=-1

q=0
Etot=-342.44
E_f0=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-345.08
E_f_p1=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*fermi+q*vbm+0.13

q=+2
Etot=-346.81
E_f_p2=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*fermi+q*vbm+0.57

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mo_Cs')

##Cd_Cs##
ncd=+1
ncs=-1

q=0
Etot=-329.28
E_f0=Etot-Eclean-ncd*u_cd-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-332.62
E_f_p1=Etot-Eclean-ncd*u_cd-ncs*u_cs+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cd_Cs')

##Zr_Cs##
nzr=+1
ncs=-1

q=0
Etot=-342.40
E_f0=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-345.07
E_f_p1=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*fermi+q*vbm+0.15

q=+2
Etot=-346.81
E_f_p2=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*fermi+q*vbm+0.59

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Zr_Cs')

##Al_Cs##
nal=+1
ncs=-1

q=0
Etot=-332.67
E_f0=Etot-Eclean-nal*u_al-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-334.42
E_f_p1=Etot-Eclean-nal*u_al-ncs*u_cs+q*fermi+q*vbm+0.09

q=+2
Etot=-335.80
E_f_p2=Etot-Eclean-nal*u_al-ncs*u_cs+q*fermi+q*vbm+0.58

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Al_Cs')

##Ga_Cs##
nga=+1
ncs=-1

q=0
Etot=-332.47
E_f0=Etot-Eclean-nga*u_ga-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-334.19
E_f_p1=Etot-Eclean-nga*u_ga-ncs*u_cs+q*fermi+q*vbm+0.15

q=+2
Etot=-335.57
E_f_p2=Etot-Eclean-nga*u_ga-ncs*u_cs+q*fermi+q*vbm+0.51

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ga_Cs')

##In_Cs##
nin=+1
ncs=-1

q=0
Etot=-332.41
E_f0=Etot-Eclean-nin*u_in-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-334.17
E_f_p1=Etot-Eclean-nin*u_in-ncs*u_cs+q*fermi+q*vbm+0.16

q=+2
Etot=-335.57
E_f_p2=Etot-Eclean-nin*u_in-ncs*u_cs+q*fermi+q*vbm+0.55

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='In_Cs')

##Sc_Cs##
nsc=+1
ncs=-1

q=0
Etot=-338.53
E_f0=Etot-Eclean-nsc*u_sc-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-342.14
E_f_p1=Etot-Eclean-nsc*u_sc-ncs*u_cs+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Sc_Cs')


##Zn_Cs##
nzn=+1
ncs=-1

q=0
Etot=-329.15
E_f0=Etot-Eclean-nzn*u_zn-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-332.06
E_f_p1=Etot-Eclean-nzn*u_zn-ncs*u_cs+q*fermi+q*vbm+0.15

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Zn_Cs')

##W_Cs##
nw=+1
ncs=-1

q=0
Etot=-342.61
E_f0=Etot-Eclean-nw*u_w-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-345.91
E_f_p1=Etot-Eclean-nw*u_w-ncs*u_cs+q*fermi+q*vbm+0.14

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='W_Cs')

##Nb_Cs##
nnb=+1
ncs=-1

q=0
Etot=-340.41
E_f0=Etot-Eclean-nnb*u_nb-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-344.57
E_f_p1=Etot-Eclean-nnb*u_nb-ncs*u_cs+q*fermi+q*vbm+0.17

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Nb_Cs')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)

ax.set_xlim([0, 1.35])
ax.set_ylim([-1.1, 4.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.32, 0.4))
plt.yticks(np.arange(-1.0, 4.01, 0.5))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=5, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.01))
#plt.savefig('Cs_site-I-rich-06-20-2024.jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
##Ca_Cs##

nca=+1
ncs=-1

q=0
Etot=-333.00
E_f0=Etot-Eclean-nca*u_ca-ncs*u_cs

q=+1
Etot=-336.52
E_f_p1=Etot-Eclean-nca*u_ca-ncs*u_cs+q*vbm+0.11

qt_Ca = (E_f_p1 - E_f0)/(-1)
print ('qca=',qt_Ca)
print (E_f0)
print (E_f_p1)


##Ba_Cs##

nba=+1
ncs=-1

q=0
Etot=-332.89
E_f0=Etot-Eclean-nba*u_ba-ncs*u_cs

q=+1
Etot=-337.80
E_f_p1=Etot-Eclean-nba*u_ba-ncs*u_cs+q*vbm+0.12

qt_Ba = (E_f_p1 - E_f0)/(-1)
print ('qba=',qt_Ba)
print (E_f0)
print (E_f_p1)


##Sr_Cs##

nsr=+1
ncs=-1

q=0
Etot=-333.46
E_f0=Etot-Eclean-nsr*u_sr-ncs*u_cs

q=+1
Etot=-336.98
E_f_p1=Etot-Eclean-nsr*u_sr-ncs*u_cs+q*vbm+0.13

qt_Sr = (E_f_p1 - E_f0)/(-1)
print ('qsr=',qt_Sr)
print (E_f0)
print (E_f_p1)

##Y_Cs##

ny=+1
ncs=-1

q=0
Etot=-338.75
E_f0=Etot-Eclean-ny*u_y-ncs*u_cs

q=+1
Etot=-342.69
E_f_p1=Etot-Eclean-ny*u_y-ncs*u_cs+q*vbm+0.08

qt_Y = (E_f_p1 - E_f0)/(-1)
print ('qy=',qt_Y)
print (E_f0)
print (E_f_p1)


##Cu_Cs##

ncu=+1
ncs=-1

q=0
Etot=-330.25
E_f0=Etot-Eclean-ncu*u_cu-ncs*u_cs

q=+1
Etot=-332.04
E_f_p1=Etot-Eclean-ncu*u_cu-ncs*u_cs+q*vbm+0.13

qt_Cu = (E_f_p1 - E_f0)/(-1)
print ('qcu=',qt_Cu)
print (E_f0)
print (E_f_p1)


##Mo_Cs##

nmo=+1
ncs=-1

q=0
Etot=-342.44
E_f0=Etot-Eclean-nmo*u_mo-ncs*u_cs

q=+1
Etot=-345.08
E_f_p1=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*vbm+0.13

qt_Mo = (E_f_p1 - E_f0)/(-1)
print ('qmo=',qt_Mo)
print (E_f0)
print (E_f_p1)


##Cd_Cs##

ncd=+1
ncs=-1

q=0
Etot=-329.28
E_f0=Etot-Eclean-ncd*u_cd-ncs*u_cs

q=+1
Etot=-332.62
E_f_p1=Etot-Eclean-ncd*u_cd-ncs*u_cs+q*vbm+0.12

qt_Cd = (E_f_p1 - E_f0)/(-1)
print ('qcd=',qt_Cd)
print (E_f0)
print (E_f_p1)


##Zr_Cs##

nzr=+1
ncs=-1

q=0
Etot=-342.40
E_f0=Etot-Eclean-nzr*u_zr-ncs*u_cs

q=+1
Etot=-345.07
E_f_p1=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*vbm+0.15

qt_Zr = (E_f_p1 - E_f0)/(-1)
print ('qzr=',qt_Zr)
print (E_f0)
print (E_f_p1)


##Al_Cs##

nal=+1
ncs=-1

q=0
Etot=-332.67
E_f0=Etot-Eclean-nal*u_al-ncs*u_cs

q=+1
Etot=-334.42
E_f_p1=Etot-Eclean-nal*u_al-ncs*u_cs+q*vbm+0.09

qt_Al = (E_f_p1 - E_f0)/(-1)
print ('qal=',qt_Al)
print (E_f0)
print (E_f_p1)


##Ga_Cs##

nga=+1
ncs=-1

q=0
Etot=-332.47
E_f0=Etot-Eclean-nga*u_ga-ncs*u_cs

q=+1
Etot=-334.19
E_f_p1=Etot-Eclean-nga*u_ga-ncs*u_cs+q*vbm+0.15

qt_Ga = (E_f_p1 - E_f0)/(-1)
print ('qga=',qt_Ga)
print (E_f0)
print (E_f_p1)


##In_Cs##

nin=+1
ncs=-1

q=0
Etot=-332.41
E_f0=Etot-Eclean-nin*u_in-ncs*u_cs

q=+1
Etot=-334.17
E_f_p1=Etot-Eclean-nin*u_in-ncs*u_cs+q*vbm+0.16

qt_In = (E_f_p1 - E_f0)/(-1)
print ('qin=',qt_In)
print (E_f0)
print (E_f_p1)


##Sc_Cs##

nsc=+1
ncs=-1

q=0
Etot=-338.53
E_f0=Etot-Eclean-nsc*u_sc-ncs*u_cs

q=+1
Etot=-342.14
E_f_p1=Etot-Eclean-nsc*u_sc-ncs*u_cs+q*vbm+0.12

qt_Sc = (E_f_p1 - E_f0)/(-1)
print ('qsc=',qt_Sc)
print (E_f0)
print (E_f_p1)


##Zn_Cs##

nzn=+1
ncs=-1

q=0
Etot=-329.15
E_f0=Etot-Eclean-nzn*u_zn-ncs*u_cs

q=+1
Etot=-332.06
E_f_p1=Etot-Eclean-nzn*u_zn-ncs*u_cs+q*vbm+0.15

qt_Zn = (E_f_p1 - E_f0)/(-1)
print ('qzn=',qt_Zn)
print (E_f0)
print (E_f_p1)


##W_Cs##

nw=+1
ncs=-1

q=0
Etot=-342.61
E_f0=Etot-Eclean-nw*u_w-ncs*u_cs

q=+1
Etot=-345.91
E_f_p1=Etot-Eclean-nw*u_w-ncs*u_cs+q*vbm+0.14

qt_W = (E_f_p1 - E_f0)/(-1)
print ('qw=',qt_W)
print (E_f0)
print (E_f_p1)


##Nb_Cs##

nnb=+1
ncs=-1

q=0
Etot=-340.41
E_f0=Etot-Eclean-nnb*u_nb-ncs*u_cs

q=+1
Etot=-344.57
E_f_p1=Etot-Eclean-nnb*u_nb-ncs*u_cs+q*vbm+0.17

qt_Nb = (E_f_p1 - E_f0)/(-1)
print ('qnb=',qt_Nb)
print (E_f0)
print (E_f_p1)
# Out:
# qca= 1.5899999999999817
# 2.239999999999977
# 0.6499999999999954
# qba= 2.970000000000025
# 2.759999999999991
# -0.21000000000003405
# qsr= 1.5700000000000385
# 1.4499999999999975
# -0.12000000000004107
# qy= 2.0399999999999974
# 3.7299999999999764
# 1.6899999999999789
# qcu= -0.15999999999997971
# 2.529999999999977
# 2.689999999999957
# qmo= 0.6899999999999862
# 2.8799999999999804
# 2.189999999999994
# qcd= 1.4000000000000314
# 1.9300000000000042
# 0.5299999999999728
# qzr= 0.7000000000000158
# 1.29
# 0.5899999999999842
# qal= -0.16000000000000014
# 2.1799999999999615
# 2.3399999999999617
# qga= -0.25000000000002953
# 1.2399999999999496
# 1.4899999999999791
# qin= -0.22000000000000908
# 0.7899999999999521
# 1.0099999999999612
# qsc= 1.6700000000000137
# 3.180000000000004
# 1.5099999999999905
# qzn= 0.940000000000025
# 2.16
# 1.219999999999975
# qw= 1.3400000000000114
# 2.849999999999965
# 1.5099999999999536
# qnb= 2.169999999999968
# 4.209999999999954
# 2.039999999999986

# %% [markdown]
# # I-poor condition

# %% [markdown]
# ## Cs-site I-poor condition

# %%
u_ca = -6.55
u_ba = -6.96
u_sr = -6.22
u_y  = -13.50
u_cu = -4.09
u_mo = -16.05
u_cd = -2.52
u_zr = -14.42
u_al = -5.87
u_ga = -4.73
u_in = -4.22
u_sc = -12.73
u_zn = -2.62
u_w  = -16.19
u_nb = -15.06

u_sn = -5.48
u_cs = -4.18

vbm = 1.82
Eclean = -332.65
fermi=np.arange(0,1.6728,0.01)

# %%
fig=plt.figure()
fig.set_size_inches(10, fig.get_figheight(), forward=True)
fig.set_size_inches(7, fig.get_figwidth(), forward=True)
ax=fig.add_subplot(1,1,1)

##Ca_Cs##
nca=+1
ncs=-1

q=0
Etot=-333.00
E_f0=Etot-Eclean-nca*u_ca-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-336.52
E_f_p1=Etot-Eclean-nca*u_ca-ncs*u_cs+q*fermi+q*vbm+0.11

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ca_Cs')

##Ba_Cs##
nba=+1
ncs=-1

q=0
Etot=-332.89
E_f0=Etot-Eclean-nba*u_ba-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-337.80
E_f_p1=Etot-Eclean-nba*u_ba-ncs*u_cs+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ba_Cs')

##Sr_Cs##
nsr=+1
ncs=-1

q=0
Etot=-333.46
E_f0=Etot-Eclean-nsr*u_sr-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-336.98
E_f_p1=Etot-Eclean-nsr*u_sr-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Sr_Cs')

##Y_Cs##
ny=+1
ncs=-1

q=0
Etot=-338.75
E_f0=Etot-Eclean-ny*u_y-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-342.69
E_f_p1=Etot-Eclean-ny*u_y-ncs*u_cs+q*fermi+q*vbm+0.08

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Y_Cs')

##Cu_Cs##
ncu=+1
ncs=-1

q=0
Etot=-330.25
E_f0=Etot-Eclean-ncu*u_cu-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-332.04
E_f_p1=Etot-Eclean-ncu*u_cu-ncs*u_cs+q*fermi+q*vbm+0.13

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cu_Cs')

##Mo_Cs##
nmo=+1
ncs=-1

q=0
Etot=-342.44
E_f0=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-345.08
E_f_p1=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*fermi+q*vbm+0.13

q=+2
Etot=-346.81
E_f_p2=Etot-Eclean-nmo*u_mo-ncs*u_cs+q*fermi+q*vbm+0.57

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Mo_Cs')

##Cd_Cs##
ncd=+1
ncs=-1

q=0
Etot=-329.28
E_f0=Etot-Eclean-ncd*u_cd-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-332.62
E_f_p1=Etot-Eclean-ncd*u_cd-ncs*u_cs+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Cd_Cs')

##Zr_Cs##
nzr=+1
ncs=-1

q=0
Etot=-342.40
E_f0=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-345.07
E_f_p1=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*fermi+q*vbm+0.15

q=+2
Etot=-346.81
E_f_p2=Etot-Eclean-nzr*u_zr-ncs*u_cs+q*fermi+q*vbm+0.59

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Zr_Cs')

##Al_Cs##
nal=+1
ncs=-1

q=0
Etot=-332.67
E_f0=Etot-Eclean-nal*u_al-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-334.42
E_f_p1=Etot-Eclean-nal*u_al-ncs*u_cs+q*fermi+q*vbm+0.09

q=+2
Etot=-335.80
E_f_p2=Etot-Eclean-nal*u_al-ncs*u_cs+q*fermi+q*vbm+0.58

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Al_Cs')

##Ga_Cs##
nga=+1
ncs=-1

q=0
Etot=-332.47
E_f0=Etot-Eclean-nga*u_ga-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-334.19
E_f_p1=Etot-Eclean-nga*u_ga-ncs*u_cs+q*fermi+q*vbm+0.15

q=+2
Etot=-335.57
E_f_p2=Etot-Eclean-nga*u_ga-ncs*u_cs+q*fermi+q*vbm+0.51

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Ga_Cs')

##In_Cs##
nin=+1
ncs=-1

q=0
Etot=-332.41
E_f0=Etot-Eclean-nin*u_in-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-334.17
E_f_p1=Etot-Eclean-nin*u_in-ncs*u_cs+q*fermi+q*vbm+0.16

q=+2
Etot=-335.57
E_f_p2=Etot-Eclean-nin*u_in-ncs*u_cs+q*fermi+q*vbm+0.55

arr=[E_f_p1,E_f_p2]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='In_Cs')

##Sc_Cs##
nsc=+1
ncs=-1

q=0
Etot=-338.53
E_f0=Etot-Eclean-nsc*u_sc-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-342.14
E_f_p1=Etot-Eclean-nsc*u_sc-ncs*u_cs+q*fermi+q*vbm+0.12

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Sc_Cs')


##Zn_Cs##
nzn=+1
ncs=-1

q=0
Etot=-329.15
E_f0=Etot-Eclean-nzn*u_zn-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-332.06
E_f_p1=Etot-Eclean-nzn*u_zn-ncs*u_cs+q*fermi+q*vbm+0.15

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Zn_Cs')

##W_Cs##
nw=+1
ncs=-1

q=0
Etot=-342.61
E_f0=Etot-Eclean-nw*u_w-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-345.91
E_f_p1=Etot-Eclean-nw*u_w-ncs*u_cs+q*fermi+q*vbm+0.14

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='W_Cs')

##Nb_Cs##
nnb=+1
ncs=-1

q=0
Etot=-340.41
E_f0=Etot-Eclean-nnb*u_nb-ncs*u_cs+q*fermi+q*vbm

q=+1
Etot=-344.57
E_f_p1=Etot-Eclean-nnb*u_nb-ncs*u_cs+q*fermi+q*vbm+0.17

arr=[E_f_p1]
Ef_min=E_f0
for i in arr:
    Ef_min=np.minimum(Ef_min,i)
plt.plot(fermi, Ef_min, linewidth=3, label='Nb_Cs')

plt.xlabel(r'Fermi level (eV)', fontsize=25)
plt.ylabel(r'Formation energy (eV)', fontsize=25)

ax.set_xlim([0, 1.35])
ax.set_ylim([-1.1, 4.1])
plt.tick_params(axis='y', width=3,length=7, labelsize=25) 
plt.tick_params(axis='x', width=3, length=7,  labelsize=25) 

ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)

plt.xticks(np.arange(0, 1.32, 0.4))
plt.yticks(np.arange(-1.0, 4.01, 0.5))
"""
ax.yaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_minor_locator(MultipleLocator(5))
plt.tick_params(axis='y', which='minor', width=1.5, length=5, color='k')
import matplotlib.ticker as tck
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())
"""
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.01))
#plt.savefig('Cs_site-I-poor-06-20-2024.jpeg', format='jpeg', dpi=300, bbox_inches='tight')
plt.show()
